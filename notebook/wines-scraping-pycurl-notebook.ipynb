# %% [markdown]
# # Vivino web scraping with Pycurl
# > Vivino has a database of 3 mln wines... this notebook won't allow you to scrape the entire website and it is mainly used to understand how to get JSON file with Pycurl and build a pandas dataframe from complex JSON. This code works on a sample of 2500 wines loaded from 100 vivino pages.
#
# ## Code and Dataset to get most of the wines
# > please refer to this code if you want to see how i have managed memory usage and saved multiple dataframes:
# Link to the final dataset:
#
# ## Premises
# > When scraping data, the most important part is the website structure analysis, in fact i have spent many hours navigating vivino website to get as much info as possible. I would like to guide you through some of the problem i have faced.
#
# ## Javascript generated content
# > For complex websites you cannot directly scrape related HTML because most of the time there will be a JavaScript script generating informations.
# I have started considering Selenium to simulate a webdriver which would have fully loaded HTML info and then parse all this info with beautiful soup.
#
# ## Selenium
# >The first problem of vivino website using Selenium was to fully load the wine list scrolling to the bottom, this require a scroll call with selenium until the end is reached, however by using this strategy you have to perform multiple calls and there may be the risk of being banned.
#
# ## Find the most important JSON (there must be one!)
# >When navigating the website i was not able to find Json file with most of the info, this is because you get such file only after you start scrolling to the end of the first page.
# "Wines info are here, there must be a file..." after a while i have found the most beautiful Json file related to wines. 725 lines of Json for each single wine.
# I immediately find out that the harderst part was not to scrape the website but to become a wine expert to take only most useful info from Json.

# %% [markdown]
# # Tables that will be created from this code
# - vintage (this is the main table)
# - region_most_used_grapes
# - flavor
#    - flavor_primary_keywords
#    - flavor_secondary_keywords
# - prices
# - food
# - grapes

# %% [markdown]
# # <b> <span style='color:#0EB1D2'>Step 1</span> <span style='color:#0EB1D2'>|</span> <span style='color:#ED6A5E ;font-style: italic;animation: pulse 2s infinite;'>Import Libraries</span></b>

# %%
import time
import pycurl
import certifi
from io import BytesIO
import json
import pandas as pd

# %%
#I just like to see all columns and more rows with full content, this option will be reset when required
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # <b> <span style='color:#0EB1D2'>Step 2</span> <span style='color:#0EB1D2'>|</span> <span style='color:#ED6A5E ;font-style: italic;animation: pulse 2s infinite;'>Scrapig with Pycurl</span></b>

# %%
# %%time
n = 0
pages_available = True
wines_collection = []

for i in range(100):
# Creating a buffer as the cURL is not allocating a buffer for the network response
    buffer = BytesIO()

# Initialising the curl object
    curl = pycurl.Curl()

# Setting the request URL, the user agent, and the buffer for the response
    url = f'https://www.vivino.com/api/explore/explore?country_code=IT&currency_code=EUR&grape_filter=varietal&min_rating=1&order_by=price&order=desc&price_range_max=500+&price_range_min=0&wine_type_ids%5B%5D=1&wine_type_ids%5B%5D=2&wine_type_ids%5B%5D=3&wine_type_ids%5B%5D=24&wine_type_ids%5B%5D=7&wine_type_ids%5B%5D=4&page={n}&language=en'
    curl.setopt(pycurl.URL, url)
    curl.setopt(pycurl.USERAGENT, "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0")
    curl.setopt(pycurl.WRITEDATA, buffer)
    curl.setopt(pycurl.CAINFO, certifi.where())

# Performing the actual request
    curl.perform()

# Accessing the response code and adding 1 to n only if successful, this step is not necessary it allows you to check each step
    if curl.getinfo(pycurl.RESPONSE_CODE) == 200:
        #print(f'Success : {n} {curl.getinfo(pycurl.RESPONSE_CODE)}', )
        n +=1
    else:
        print(f'Not Success{curl.getinfo(pycurl.RESPONSE_CODE)}')

# Ending the session and freeing the resources
    curl.close()
    
#Convert Buffer from Byte to string to Dict
    page_dict = json.loads(buffer.getvalue().decode())

#page_dict is now a dictionaire containing three main dictionaries, the one we want is "explore_vintage", it contains another dict "matches"
#matches is a list of dict
    for i in page_dict['explore_vintage']['matches']:
        wines_collection.append(i)
    
    if n%10 == 0:
        print(len(wines_collection))
# Out:
# 250
# 500
# 750
# 1000
# 1250
# 1500
# 1750
# 2000
# 2250
# 2500
# CPU times: user 5.61 s, sys: 1.01 s, total: 6.62 s
# Wall time: 1min 35s

# %% [markdown]
# # <b> <span style='color:#0EB1D2'>Step 3</span> <span style='color:#0EB1D2'>|</span> <span style='color:#ED6A5E ;font-style: italic;animation: pulse 2s infinite;'>Optional - Check saved content in Buffer</span></b>
# >When we save our scraped content into a buffer this will be in bytes format, we use decode to convert it into string and then json library to finally get a dictionary we can work with

# %%
#buffer getvalue() now store informations we need in a bytes format
print(type(buffer.getvalue()))

#hence we will decode bytes into string
string = buffer.getvalue().decode()
print(type(string))

#at this stage we can  convert our string into a dictionary using json library
wines_info = json.loads(string)
print(type(wines_info))

# %%
#We have three main keys
print(wines_info.keys())
#explore vintage has more keys
print(wines_info['explore_vintage'].keys())
#matches provides a list of values, let's see keys of the first value of this list
print(wines_info['explore_vintage']['matches'][0].keys())
print(wines_info['explore_vintage']['matches'][0]['vintage'].keys())

# %%
#let's take the first wine of the list JSON, you can copy and paste it in a Json formatter or just use visual studio
wines_collection[0]

# %% [markdown]
# # <b> <span style='color:#0EB1D2'>Step 3</span> <span style='color:#0EB1D2'>|</span> <span style='color:#ED6A5E ;font-style: italic;animation: pulse 2s infinite;'>Pandas Dataframe</span></b>

# %% [markdown]
# ## Main Table
# as you can see we have now a very clear dataset with lots of variables, please note that the following variables are still a list of dictionaries:
# - prices
# - most_used_grapes
# - flavor
# - food
# - grapes

# %%
pd.reset_option('display.max_colwidth')
vintage = pd.json_normalize(wines_collection)
vintage.head()
# Out:
#                                               prices  vintage.id  \
# 0  [{'id': 35134561, 'merchant_id': 18999, 'amoun...   156099154
# 1  [{'id': 34993404, 'merchant_id': 18999, 'amoun...   156856757
# 2  [{'id': 33381495, 'merchant_id': 18999, 'amoun...   159343591
# 3  [{'id': 22633878, 'merchant_id': 18999, 'amoun...     1746707
# 4  [{'id': 22633879, 'merchant_id': 18999, 'amoun...    14162009
#
#                                     vintage.seo_name  \
# 0  domaine-de-la-romanee-conti-romanee-conti-gran...
# 1  egon-muller-scharzhof-riesling-scharzhofberger...
# 2                        chateau-petrus-pomerol-2019
# 3                        chateau-petrus-pomerol-2009
# 4                        chateau-petrus-pomerol-2015
#
#                                         vintage.name  \
# 0  Domaine de La Romanée-Conti Romanée-Conti Gran...
# 1  Egon Müller - Scharzhof Scharzhofberger Riesli...
# 2                        Château Pétrus Pomerol 2019
# 3                        Château Pétrus Pomerol 2009
# 4                        Château Pétrus Pomerol 2015
#
#   vintage.statistics.status  vintage.statistics.ratings_count  \
# 0                    Normal                                52
# 1                    Normal                               129
# 2                    Normal                                62
# 3                    Normal                               628
# 4                    Normal                               245
#
#    vintage.statistics.ratings_average  vintage.statistics.labels_count  \
# 0                                 4.6                              807
# 1                                 4.5                               21
# 2                                 4.6                              965
# 3                                 4.7                             7341
# 4                                 4.7                             3619
#
#    vintage.statistics.wine_ratings_count  \
# 0                                   9989
# 1                                    129
# 2                                  34983
# 3                                  34983
# 4                                  34983
#
#    vintage.statistics.wine_ratings_average vintage.statistics.wine_status  \
# 0                                      4.7
# 1                                      4.5
# 2                                      4.7
# 3                                      4.7
# 4                                      4.7
#
#                               vintage.image.location  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                vintage.image.variations.bottle_large  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#               vintage.image.variations.bottle_medium  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#        vintage.image.variations.bottle_medium_square  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                vintage.image.variations.bottle_small  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#         vintage.image.variations.bottle_small_square  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                       vintage.image.variations.label  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                 vintage.image.variations.label_large  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                vintage.image.variations.label_medium  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#         vintage.image.variations.label_medium_square  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#          vintage.image.variations.label_small_square  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                       vintage.image.variations.large  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                      vintage.image.variations.medium  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#               vintage.image.variations.medium_square  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...
#
#                vintage.image.variations.small_square  vintage.wine.id  \
# 0  //images.vivino.com/thumbs/SzZEjTsMRlWz3yDyCIS...            83912
# 1  //images.vivino.com/thumbs/cLYqTSHrR1-d3STofSx...          1513593
# 2  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...          1166837
# 3  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...          1166837
# 4  //images.vivino.com/thumbs/RPhc1fBwT0uLKoE6_mt...          1166837
#
#                                vintage.wine.name  \
# 0                        Romanée-Conti Grand Cru
# 1  Scharzhofberger Riesling Trockenbeerenauslese
# 2                                        Pomerol
# 3                                        Pomerol
# 4                                        Pomerol
#
#                            vintage.wine.seo_name  vintage.wine.type_id  \
# 0                        romanee-conti-grand-cru                     1
# 1  riesling-scharzhofberger-trockenbeerenauslese                     7
# 2                                        pomerol                     1
# 3                                        pomerol                     1
# 4                                        pomerol                     1
#
#    vintage.wine.vintage_type  vintage.wine.is_natural  vintage.wine.region.id  \
# 0                          0                    False                    2228
# 1                          0                    False                    3150
# 2                          0                    False                     555
# 3                          0                    False                     555
# 4                          0                    False                     555
#
#   vintage.wine.region.name vintage.wine.region.name_en  \
# 0  Romanée-Conti Grand Cru               Romanée-Conti
# 1                Wiltingen
# 2                  Pomerol
# 3                  Pomerol
# 4                  Pomerol
#
#   vintage.wine.region.seo_name vintage.wine.region.country.code  \
# 0                romanee-conti                               fr
# 1                    wiltingen                               de
# 2                      pomerol                               fr
# 3                      pomerol                               fr
# 4                      pomerol                               fr
#
#   vintage.wine.region.country.name vintage.wine.region.country.native_name  \
# 0                           France                                  France
# 1                          Germany                             Deutschland
# 2                           France                                  France
# 3                           France                                  France
# 4                           France                                  France
#
#   vintage.wine.region.country.seo_name  \
# 0                               france
# 1                              germany
# 2                               france
# 3                               france
# 4                               france
#
#   vintage.wine.region.country.currency.code  \
# 0                                       EUR
# 1                                       EUR
# 2                                       EUR
# 3                                       EUR
# 4                                       EUR
#
#   vintage.wine.region.country.currency.name  \
# 0                                     Euros
# 1                                     Euros
# 2                                     Euros
# 3                                     Euros
# 4                                     Euros
#
#   vintage.wine.region.country.currency.prefix  \
# 0                                           €
# 1                                           €
# 2                                           €
# 3                                           €
# 4                                           €
#
#   vintage.wine.region.country.currency.suffix  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
#
#    vintage.wine.region.country.regions_count  \
# 0                                       1308
# 1                                        237
# 2                                       1308
# 3                                       1308
# 4                                       1308
#
#    vintage.wine.region.country.users_count  \
# 0                                  6765384
# 1                                  2824426
# 2                                  6765384
# 3                                  6765384
# 4                                  6765384
#
#    vintage.wine.region.country.wines_count  \
# 0                                   440033
# 1                                   174150
# 2                                   440033
# 3                                   440033
# 4                                   440033
#
#    vintage.wine.region.country.wineries_count  \
# 0                                       68410
# 1                                       13728
# 2                                       68410
# 3                                       68410
# 4                                       68410
#
#         vintage.wine.region.country.most_used_grapes  \
# 0  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 1  [{'id': 15, 'name': 'Riesling', 'seo_name': 'r...
# 2  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 3  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 4  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
#
#    vintage.wine.region.background_image  vintage.wine.winery.id  \
# 0                                   NaN                   11610
# 1                                   NaN                    2197
# 2                                   NaN                   12630
# 3                                   NaN                   12630
# 4                                   NaN                   12630
#
#       vintage.wine.winery.name vintage.wine.winery.seo_name  \
# 0  Domaine de La Romanée-Conti  domaine-de-la-romanee-conti
# 1      Egon Müller - Scharzhof        egon-muller-scharzhof
# 2               Château Pétrus               chateau-petrus
# 3               Château Pétrus               chateau-petrus
# 4               Château Pétrus               chateau-petrus
#
#    vintage.wine.winery.status  vintage.wine.winery.background_image  \
# 0                           0                                   NaN
# 1                           0                                   NaN
# 2                           0                                   NaN
# 3                           0                                   NaN
# 4                           0                                   NaN
#
#    vintage.wine.taste.structure.acidity  \
# 0                                  4.09
# 1                                   NaN
# 2                                  3.37
# 3                                  3.37
# 4                                  3.37
#
#    vintage.wine.taste.structure.fizziness  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    vintage.wine.taste.structure.intensity  \
# 0                                    3.04
# 1                                     NaN
# 2                                    4.13
# 3                                    4.13
# 4                                    4.13
#
#    vintage.wine.taste.structure.sweetness  \
# 0                                    1.96
# 1                                     NaN
# 2                                    1.97
# 3                                    1.97
# 4                                    1.97
#
#    vintage.wine.taste.structure.tannin  \
# 0                                 2.50
# 1                                  NaN
# 2                                 3.45
# 3                                 3.45
# 4                                 3.45
#
#    vintage.wine.taste.structure.user_structure_count  \
# 0                                              362.0
# 1                                                NaN
# 2                                              737.0
# 3                                              737.0
# 4                                              737.0
#
#    vintage.wine.taste.structure.calculated_structure_count  \
# 0                                              159.0
# 1                                                NaN
# 2                                              751.0
# 3                                              751.0
# 4                                              751.0
#
#                            vintage.wine.taste.flavor vintage.wine.statistics  \
# 0  [{'group': 'red_fruit', 'stats': {'count': 87,...                    None
# 1  [{'group': 'earth', 'stats': {'count': 6, 'sco...                    None
# 2  [{'group': 'oak', 'stats': {'count': 585, 'sco...                    None
# 3  [{'group': 'oak', 'stats': {'count': 585, 'sco...                    None
# 4  [{'group': 'oak', 'stats': {'count': 585, 'sco...                    None
#
#    vintage.wine.style.id  vintage.wine.style.seo_name  \
# 0                  283.0   burgundy-cote-de-nuits-red
# 1                    NaN                          NaN
# 2                  267.0  bordeaux-right-bank-pomerol
# 3                  267.0  bordeaux-right-bank-pomerol
# 4                  267.0  bordeaux-right-bank-pomerol
#
#   vintage.wine.style.regional_name vintage.wine.style.varietal_name  \
# 0                         Burgundy                Côte de Nuits Red
# 1                              NaN                              NaN
# 2              Bordeaux Right Bank                          Pomerol
# 3              Bordeaux Right Bank                          Pomerol
# 4              Bordeaux Right Bank                          Pomerol
#
#       vintage.wine.style.name  vintage.wine.style.background_image  \
# 0  Burgundy Côte de Nuits Red                                  NaN
# 1                         NaN                                  NaN
# 2            Bordeaux Pomerol                                  NaN
# 3            Bordeaux Pomerol                                  NaN
# 4            Bordeaux Pomerol                                  NaN
#
#    vintage.wine.style.image  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                       vintage.wine.style.description vintage.wine.style.blurb  \
# 0                                               None                     None
# 1                                                NaN                      NaN
# 2  Bordeaux Pomerol wines are rich, decadent reds...                     None
# 3  Bordeaux Pomerol wines are rich, decadent reds...                     None
# 4  Bordeaux Pomerol wines are rich, decadent reds...                     None
#
#                 vintage.wine.style.interesting_facts  vintage.wine.style.body  \
# 0                                               None                      3.0
# 1                                                NaN                      NaN
# 2  [Pomerol is the smallest of Bordeaux's major a...                      4.0
# 3  [Pomerol is the smallest of Bordeaux's major a...                      4.0
# 4  [Pomerol is the smallest of Bordeaux's major a...                      4.0
#
#   vintage.wine.style.body_description  vintage.wine.style.acidity  \
# 0                       Medium-bodied                         3.0
# 1                                 NaN                         NaN
# 2                         Full-bodied                         2.0
# 3                         Full-bodied                         2.0
# 4                         Full-bodied                         2.0
#
#   vintage.wine.style.acidity_description vintage.wine.style.country.code  \
# 0                                   High                              fr
# 1                                    NaN                             NaN
# 2                                 Medium                              fr
# 3                                 Medium                              fr
# 4                                 Medium                              fr
#
#   vintage.wine.style.country.name vintage.wine.style.country.native_name  \
# 0                          France                                 France
# 1                             NaN                                    NaN
# 2                          France                                 France
# 3                          France                                 France
# 4                          France                                 France
#
#   vintage.wine.style.country.seo_name  \
# 0                              france
# 1                                 NaN
# 2                              france
# 3                              france
# 4                              france
#
#   vintage.wine.style.country.currency.code  \
# 0                                      EUR
# 1                                      NaN
# 2                                      EUR
# 3                                      EUR
# 4                                      EUR
#
#   vintage.wine.style.country.currency.name  \
# 0                                    Euros
# 1                                      NaN
# 2                                    Euros
# 3                                    Euros
# 4                                    Euros
#
#   vintage.wine.style.country.currency.prefix  \
# 0                                          €
# 1                                        NaN
# 2                                          €
# 3                                          €
# 4                                          €
#
#    vintage.wine.style.country.currency.suffix  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    vintage.wine.style.country.regions_count  \
# 0                                    1308.0
# 1                                       NaN
# 2                                    1308.0
# 3                                    1308.0
# 4                                    1308.0
#
#    vintage.wine.style.country.users_count  \
# 0                               6765384.0
# 1                                     NaN
# 2                               6765384.0
# 3                               6765384.0
# 4                               6765384.0
#
#    vintage.wine.style.country.wines_count  \
# 0                                440033.0
# 1                                     NaN
# 2                                440033.0
# 3                                440033.0
# 4                                440033.0
#
#    vintage.wine.style.country.wineries_count  \
# 0                                    68410.0
# 1                                        NaN
# 2                                    68410.0
# 3                                    68410.0
# 4                                    68410.0
#
#          vintage.wine.style.country.most_used_grapes  \
# 0  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 1                                                NaN
# 2  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 3  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 4  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
#
#    vintage.wine.style.wine_type_id  \
# 0                              1.0
# 1                              NaN
# 2                              1.0
# 3                              1.0
# 4                              1.0
#
#                              vintage.wine.style.food  \
# 0  [{'id': 4, 'name': 'Beef', 'weight': 0.5, 'bac...
# 1                                                NaN
# 2  [{'id': 4, 'name': 'Beef', 'weight': 0.5, 'bac...
# 3  [{'id': 4, 'name': 'Beef', 'weight': 0.5, 'bac...
# 4  [{'id': 4, 'name': 'Beef', 'weight': 0.5, 'bac...
#
#                            vintage.wine.style.grapes  \
# 0  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 1                                                NaN
# 2  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 3  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
# 4  [{'id': 2, 'name': 'Cabernet Sauvignon', 'seo_...
#
#    vintage.wine.style.region.id vintage.wine.style.region.name  \
# 0                         408.0                  Côte de Nuits
# 1                           NaN                            NaN
# 2                         555.0                        Pomerol
# 3                         555.0                        Pomerol
# 4                         555.0                        Pomerol
#
#   vintage.wine.style.region.name_en vintage.wine.style.region.seo_name  \
# 0                                                        cote-de-nuits
# 1                               NaN                                NaN
# 2                                                              pomerol
# 3                                                              pomerol
# 4                                                              pomerol
#
#   vintage.wine.style.region.country.code  \
# 0                                     fr
# 1                                    NaN
# 2                                     fr
# 3                                     fr
# 4                                     fr
#
#   vintage.wine.style.region.country.name  \
# 0                                 France
# 1                                    NaN
# 2                                 France
# 3                                 France
# 4                                 France
#
#   vintage.wine.style.region.country.native_name  \
# 0                                        France
# 1                                           NaN
# 2                                        France
# 3                                        France
# 4                                        France
#
#   vintage.wine.style.region.country.seo_name  \
# 0                                     france
# 1                                        NaN
# 2                                     france
# 3                                     france
# 4                                     france
#
#   vintage.wine.style.region.country.currency.code  \
# 0                                             EUR
# 1                                             NaN
# 2                                             EUR
# 3                                             EUR
# 4                                             EUR
#
#   vintage.wine.style.region.country.currency.name  \
# 0                                           Euros
# 1                                             NaN
# 2                                           Euros
# 3                                           Euros
# 4                                           Euros
#
#   vintage.wine.style.region.country.currency.prefix  \
# 0                                                 €
# 1                                               NaN
# 2                                                 €
# 3                                                 €
# 4                                                 €
#
#    vintage.wine.style.region.country.currency.suffix  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    vintage.wine.style.region.country.regions_count  \
# 0                                           1308.0
# 1                                              NaN
# 2                                           1308.0
# 3                                           1308.0
# 4                                           1308.0
#
#    vintage.wine.style.region.country.users_count  \
# 0                                      6765384.0
# 1                                            NaN
# 2                                      6765384.0
# 3                                      6765384.0
# 4                                      6765384.0
#
#    vintage.wine.style.region.country.wines_count  \
# 0                                       440033.0
# 1                                            NaN
# 2                                       440033.0
# 3                                       440033.0
# 4                                       440033.0
#
#    vintage.wine.style.region.country.wineries_count  \
# 0                                           68410.0
# 1                                               NaN
# 2                                           68410.0
# 3                                           68410.0
# 4                                           68410.0
#
#   vintage.wine.style.region.country.most_used_grapes  \
# 0  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 1                                                NaN
# 2  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 3  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 4  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
#
#    vintage.wine.style.region.parent_id  \
# 0                                385.0
# 1                                  NaN
# 2                                509.0
# 3                                509.0
# 4                                509.0
#
#   vintage.wine.style.region.background_image.location  \
# 0  //images.vivino.com/regions/backgrounds/oTEcWw...
# 1                                                NaN
# 2  //images.vivino.com/regions/backgrounds/OWIaZW...
# 3  //images.vivino.com/regions/backgrounds/OWIaZW...
# 4  //images.vivino.com/regions/backgrounds/OWIaZW...
#
#   vintage.wine.style.region.background_image.variations.large  \
# 0  //thumbs.vivino.com/region_backgrounds/oTEcWwU...
# 1                                                NaN
# 2  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 3  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 4  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
#
#   vintage.wine.style.region.background_image.variations.medium  \
# 0  //thumbs.vivino.com/region_backgrounds/oTEcWwU...
# 1                                                NaN
# 2  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 3  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 4  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
#
#    vintage.wine.style.region.statistics.wineries_count  \
# 0                                              765.0
# 1                                                NaN
# 2                                              307.0
# 3                                              307.0
# 4                                              307.0
#
#    vintage.wine.style.region.statistics.wines_count  \
# 0                                            7413.0
# 1                                               NaN
# 2                                             880.0
# 3                                             880.0
# 4                                             880.0
#
#    vintage.wine.style.region.statistics.sub_regions_count  \
# 0                                               11.0
# 1                                                NaN
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    vintage.wine.style.region.statistics.parent_regions_count  \
# 0                                                1.0
# 1                                                NaN
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
#
#    vintage.wine.style.parent_style_id vintage.wine.style.hidden  \
# 0                                23.0                     False
# 1                                 NaN                       NaN
# 2                               268.0                     False
# 3                               268.0                     False
# 4                               268.0                     False
#
#    vintage.wine.style.statistics.wines_count  \
# 0                                    13772.0
# 1                                        NaN
# 2                                      902.0
# 3                                      902.0
# 4                                      902.0
#
#    vintage.wine.style.statistics.aggregated_wines_count  \
# 0                                            13772.0
# 1                                                NaN
# 2                                              902.0
# 3                                              902.0
# 4                                              902.0
#
#   vintage.wine.style.vintage_mask  \
# 0                              1<
# 1                             NaN
# 2                              1<
# 3                              1<
# 4                              1<
#
#    vintage.wine.style.baseline_structure.acidity  \
# 0                                            4.5
# 1                                            NaN
# 2                                            3.5
# 3                                            3.5
# 4                                            3.5
#
#    vintage.wine.style.baseline_structure.fizziness  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    vintage.wine.style.baseline_structure.intensity  \
# 0                                              3.0
# 1                                              NaN
# 2                                              4.5
# 3                                              4.5
# 4                                              4.5
#
#    vintage.wine.style.baseline_structure.sweetness  \
# 0                                              1.0
# 1                                              NaN
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
#
#    vintage.wine.style.baseline_structure.tannin  \
# 0                                           2.5
# 1                                           NaN
# 2                                           4.0
# 3                                           4.0
# 4                                           4.0
#
#    vintage.wine.has_valid_ratings vintage.year vintage.grapes  \
# 0                           False         2018           None
# 1                           False         2018           None
# 2                           False         2019           None
# 3                           False         2009           None
# 4                           False         2015           None
#
#    vintage.has_valid_ratings  price.id  price.merchant_id  price.amount  \
# 0                       True  35134561              18999      50960.00
# 1                       True  34993404              18999      16621.89
# 2                       True  33381495              18999      13613.25
# 3                       True  22633878              18999      13106.10
# 4                       True  22633879              18999      11989.95
#
#    price.discounted_from  price.discount_percent price.type   price.sku  \
# 0                    NaN                     NaN         vc  MTH2204156
# 1                    NaN                     NaN         vc      CTH493
# 2                    NaN                     NaN         vc     NND2559
# 3                    NaN                     NaN         vc     NND2117
# 4                    NaN                     NaN         vc     NND2555
#
#                                            price.url  price.visibility  \
# 0  https://www.soloprodottiitaliani.it/spec_colle...                 1
# 1  https://www.soloprodottiitaliani.it/spec_colle...                 1
# 2  https://www.soloprodottiitaliani.it/spec_colle...                 1
# 3  https://www.soloprodottiitaliani.it/spec_colle...                 1
# 4  https://www.soloprodottiitaliani.it/spec_colle...                 1
#
#    price.bottle_type_id price.currency.code price.currency.name  \
# 0                     1                 EUR               Euros
# 1                     1                 EUR               Euros
# 2                     1                 EUR               Euros
# 3                     1                 EUR               Euros
# 4                     1                 EUR               Euros
#
#   price.currency.prefix price.currency.suffix  price.xms  price.xmphs  \
# 0                     €                  None   0.541159        False
# 1                     €                  None   0.541159        False
# 2                     €                  None   0.541159        False
# 3                     €                  None   0.541159        False
# 4                     €                  None   0.541159        False
#
#   price.price_group_id  price.vfm_score  price.vfm_category.id  \
# 0                [xom]              0.0                      0
# 1                [xom]              0.0                      0
# 2                [xom]              0.0                      0
# 3                [xom]              0.0                      0
# 4                [xom]              0.0                      0
#
#   price.vfm_category.title                        price.vfm_category.subtitle  \
# 0        Value Unavailable  We’re still gathering data to determine this w...
# 1        Value Unavailable  We’re still gathering data to determine this w...
# 2        Value Unavailable  We’re still gathering data to determine this w...
# 3        Value Unavailable  We’re still gathering data to determine this w...
# 4        Value Unavailable  We’re still gathering data to determine this w...
#
#   price.vfm_category.barometer_position  price.bottle_type.id  \
# 0                                  None                     1
# 1                                  None                     1
# 2                                  None                     1
# 3                                  None                     1
# 4                                  None                     1
#
#   price.bottle_type.name price.bottle_type.short_name  \
# 0         Bottle (0.75l)                       bottle
# 1         Bottle (0.75l)                       bottle
# 2         Bottle (0.75l)                       bottle
# 3         Bottle (0.75l)                       bottle
# 4         Bottle (0.75l)                       bottle
#
#   price.bottle_type.short_name_plural  price.bottle_type.volume_ml  \
# 0                             bottles                          750
# 1                             bottles                          750
# 2                             bottles                          750
# 3                             bottles                          750
# 4                             bottles                          750
#
#    vintage.wine.taste.structure  vintage.wine.style  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
#
#        vintage.wine.region.background_image.location  \
# 0                                                NaN
# 1                                                NaN
# 2  //images.vivino.com/regions/backgrounds/OWIaZW...
# 3  //images.vivino.com/regions/backgrounds/OWIaZW...
# 4  //images.vivino.com/regions/backgrounds/OWIaZW...
#
#   vintage.wine.region.background_image.variations.large  \
# 0                                                NaN
# 1                                                NaN
# 2  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 3  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 4  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
#
#   vintage.wine.region.background_image.variations.medium  \
# 0                                                NaN
# 1                                                NaN
# 2  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 3  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 4  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
#
#                            vintage.top_list_rankings  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'rank': 1, 'previous_rank': 1, 'description'...
# 4                                                NaN
#
#   vintage.wine.winery.background_image.location  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   vintage.wine.winery.background_image.variations.large  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   vintage.wine.winery.background_image.variations.medium  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   vintage.wine.winery.background_image.variations.small  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    vintage.wine.style.region.background_image  vintage.wine.style.region  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
#
#   vintage.wine.style.image.location
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN

# %% [markdown]
# ## Subtables with json_normalize
# transform list of dictionaries within the main dataset to many subdatasets that can be used by joining with the wine id (vintage.id)

# %% [markdown]
# ### vintage.wine.region.country.most_used_grapes

# %%
pd.reset_option('display.max_colwidth')
region_most_used_grapes = pd.json_normalize(wines_collection,
                                     record_path = ['vintage', 'wine', 'region', 'country', 'most_used_grapes'],
                                     record_prefix = 'vintage_wine_region_country_MostUsedGrapes_', meta = [['vintage', 'id']])
region_most_used_grapes.head(10)
# Out:
#    vintage_wine_region_country_MostUsedGrapes_id  \
# 0                                             14
# 1                                              5
# 2                                             10
# 3                                             15
# 4                                            299
# 5                                            355
# 6                                             14
# 7                                              5
# 8                                             10
# 9                                             14
#
#   vintage_wine_region_country_MostUsedGrapes_name  \
# 0                                      Pinot Noir
# 1                                      Chardonnay
# 2                                          Merlot
# 3                                        Riesling
# 4                                   Spätburgunder
# 5                                  Weissburgunder
# 6                                      Pinot Noir
# 7                                      Chardonnay
# 8                                          Merlot
# 9                                      Pinot Noir
#
#   vintage_wine_region_country_MostUsedGrapes_seo_name  \
# 0                                         pinot-noir
# 1                                         chardonnay
# 2                                             merlot
# 3                                           riesling
# 4                                      spatburgunder
# 5                                     weissburgunder
# 6                                         pinot-noir
# 7                                         chardonnay
# 8                                             merlot
# 9                                         pinot-noir
#
#    vintage_wine_region_country_MostUsedGrapes_has_detailed_info  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                              False
# 5                                              False
# 6                                               True
# 7                                               True
# 8                                               True
# 9                                               True
#
#    vintage_wine_region_country_MostUsedGrapes_wines_count  \
# 0                                             572334
# 1                                             604208
# 2                                             566719
# 3                                             262136
# 4                                              50164
# 5                                              33464
# 6                                             572334
# 7                                             604208
# 8                                             566719
# 9                                             572334
#
#    vintage_wine_region_country_MostUsedGrapes_parent_grape_id vintage.id
# 0                                                NaN           156099154
# 1                                                NaN           156099154
# 2                                                NaN           156099154
# 3                                                NaN           156856757
# 4                                               14.0           156856757
# 5                                               36.0           156856757
# 6                                                NaN           159343591
# 7                                                NaN           159343591
# 8                                                NaN           159343591
# 9                                                NaN             1746707

# %% [markdown]
# ### vintage.wine.taste.flavor
# flavor has two other nested dictionaries primary_key and secondary_key to get the specific main flavor components, we can associate them as flavor notes, in my opinion the flavor group would be enough

# %%
vintage['vintage.wine.taste.flavor'].isna().sum()
# Out:
# np.int64(0)

# %%
flavor = pd.json_normalize(wines_collection,
                                     record_path = ['vintage', 'wine', 'taste', 'flavor'], meta = [['vintage', 'id']])
flavor.head(10)
# Out:
#           group                                   primary_keywords  \
# 0     red_fruit  [{'id': 348, 'name': 'raspberry', 'count': 34}...
# 1         earth  [{'id': 242, 'name': 'leather', 'count': 33}, ...
# 2           oak  [{'id': 292, 'name': 'oak', 'count': 11}, {'id...
# 3   black_fruit  [{'id': 38, 'name': 'black cherry', 'count': 1...
# 4       non_oak  [{'id': 62, 'name': 'brioche', 'count': 1}, {'...
# 5        spices  [{'id': 320, 'name': 'pepper', 'count': 6}, {'...
# 6        floral  [{'id': 322, 'name': 'perfume', 'count': 5}, {...
# 7      microbio  [{'id': 238, 'name': 'lager', 'count': 1}, {'i...
# 8  citrus_fruit  [{'id': 298, 'name': 'orange', 'count': 3}, {'...
# 9   dried_fruit  [{'id': 341, 'name': 'prune', 'count': 2}, {'i...
#
#                                   secondary_keywords  stats.count  \
# 0  [{'id': 38, 'name': 'black cherry', 'count': 1...           87
# 1  [{'id': 422, 'name': 'tobacco', 'count': 3}, {...           73
# 2  [{'id': 242, 'name': 'leather', 'count': 33}, ...           69
# 3         [{'id': 341, 'name': 'prune', 'count': 2}]           49
# 4  [{'id': 384, 'name': 'smoke', 'count': 7}, {'i...           30
# 5  [{'id': 434, 'name': 'vanilla', 'count': 2}, {...           21
# 6        [{'id': 381, 'name': 'savory', 'count': 2}]           19
# 7  [{'id': 284, 'name': 'mushroom', 'count': 9}, ...           12
# 8                                                NaN            7
# 9           [{'id': 229, 'name': 'jam', 'count': 1}]            5
#
#    stats.score vintage.id
# 0        11822  156099154
# 1         8582  156099154
# 2         4570  156099154
# 3         6034  156099154
# 4          603  156099154
# 5         2195  156099154
# 6         2050  156099154
# 7          700  156099154
# 8          700  156099154
# 9          394  156099154

# %% [markdown]
# ### Prices
# wine price is already included into the main table as a float value, this table contains prices related with the id of the vendor

# %%
vintage['prices'].isna().sum()
# Out:
# np.int64(0)

# %%
pd.reset_option('display.max_colwidth')
prices = pd.json_normalize(wines_collection,
                                     record_path = 'prices',
                                     record_prefix = 'prices_', meta = [['vintage', 'id']])
prices.head(10)
# Out:
#    prices_id  prices_merchant_id  prices_amount  prices_discounted_from  \
# 0   35134561               18999       50960.00                     NaN
# 1   34993404               18999       16621.89                     NaN
# 2   33381495               18999       13613.25                     NaN
# 3   22633878               18999       13106.10                     NaN
# 4   22633879               18999       11989.95                     NaN
# 5   36150812               18999       11892.30                     NaN
# 6   26301254               18999       11239.20                     NaN
# 7   36150813               18999       10943.10                     NaN
# 8   29295725               18999       10943.10                     NaN
# 9   22633877               18999       10943.10                     NaN
#
#    prices_discount_percent prices_type  prices_sku  \
# 0                      NaN          vc  MTH2204156
# 1                      NaN          vc      CTH493
# 2                      NaN          vc     NND2559
# 3                      NaN          vc     NND2117
# 4                      NaN          vc     NND2555
# 5                      NaN          vc     NND2116
# 6                      NaN          vc     NND2558
# 7                      NaN          vc     NND2118
# 8                      NaN          vc     NND2114
# 9                      NaN          vc     NND2115
#
#                                           prices_url  prices_visibility  \
# 0  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 1  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 2  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 3  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 4  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 5  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 6  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 7  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 8  https://www.soloprodottiitaliani.it/spec_colle...                  1
# 9  https://www.soloprodottiitaliani.it/spec_colle...                  1
#
#    prices_bottle_type_id  prices_xms  prices_xmphs prices_price_group_id  \
# 0                      1    0.541159         False                 [xom]
# 1                      1    0.541159         False                 [xom]
# 2                      1    0.541159         False                 [xom]
# 3                      1    0.541159         False                 [xom]
# 4                      1    0.541159         False                 [xom]
# 5                      1    0.541159         False                 [xom]
# 6                      1    0.541159         False                 [xom]
# 7                      1    0.541159         False                 [xom]
# 8                      1    0.541159         False                 [xom]
# 9                      1    0.541159         False                 [xom]
#
#    prices_vfm_score prices_currency.code prices_currency.name  \
# 0               0.0                  EUR                Euros
# 1               0.0                  EUR                Euros
# 2               0.0                  EUR                Euros
# 3               0.0                  EUR                Euros
# 4               0.0                  EUR                Euros
# 5               0.0                  EUR                Euros
# 6               0.0                  EUR                Euros
# 7               0.0                  EUR                Euros
# 8               0.0                  EUR                Euros
# 9               0.0                  EUR                Euros
#
#   prices_currency.prefix prices_currency.suffix  prices_vfm_category.id  \
# 0                      €                   None                       0
# 1                      €                   None                       0
# 2                      €                   None                       0
# 3                      €                   None                       0
# 4                      €                   None                       0
# 5                      €                   None                       0
# 6                      €                   None                       0
# 7                      €                   None                       0
# 8                      €                   None                       0
# 9                      €                   None                       0
#
#   prices_vfm_category.title  \
# 0         Value Unavailable
# 1         Value Unavailable
# 2         Value Unavailable
# 3         Value Unavailable
# 4         Value Unavailable
# 5         Value Unavailable
# 6         Value Unavailable
# 7         Value Unavailable
# 8         Value Unavailable
# 9         Value Unavailable
#
#                         prices_vfm_category.subtitle  \
# 0  We’re still gathering data to determine this w...
# 1  We’re still gathering data to determine this w...
# 2  We’re still gathering data to determine this w...
# 3  We’re still gathering data to determine this w...
# 4  We’re still gathering data to determine this w...
# 5  We’re still gathering data to determine this w...
# 6  We’re still gathering data to determine this w...
# 7  We’re still gathering data to determine this w...
# 8  We’re still gathering data to determine this w...
# 9  We’re still gathering data to determine this w...
#
#   prices_vfm_category.barometer_position  prices_bottle_type.id  \
# 0                                   None                      1
# 1                                   None                      1
# 2                                   None                      1
# 3                                   None                      1
# 4                                   None                      1
# 5                                   None                      1
# 6                                   None                      1
# 7                                   None                      1
# 8                                   None                      1
# 9                                   None                      1
#
#   prices_bottle_type.name prices_bottle_type.short_name  \
# 0          Bottle (0.75l)                        bottle
# 1          Bottle (0.75l)                        bottle
# 2          Bottle (0.75l)                        bottle
# 3          Bottle (0.75l)                        bottle
# 4          Bottle (0.75l)                        bottle
# 5          Bottle (0.75l)                        bottle
# 6          Bottle (0.75l)                        bottle
# 7          Bottle (0.75l)                        bottle
# 8          Bottle (0.75l)                        bottle
# 9          Bottle (0.75l)                        bottle
#
#   prices_bottle_type.short_name_plural  prices_bottle_type.volume_ml  \
# 0                              bottles                           750
# 1                              bottles                           750
# 2                              bottles                           750
# 3                              bottles                           750
# 4                              bottles                           750
# 5                              bottles                           750
# 6                              bottles                           750
# 7                              bottles                           750
# 8                              bottles                           750
# 9                              bottles                           750
#
#   vintage.id
# 0  156099154
# 1  156856757
# 2  159343591
# 3    1746707
# 4   14162009
# 5    1759463
# 6  156099048
# 7  162902104
# 8    2893744
# 9    1921204

# %% [markdown]
# ## Subtables without json_normalize

# %% [markdown]
# #### Flavor primary_keyboards and secondary_keywords
# some variables like, flavor primary_keyboards and secondary_keywords are not always populated and it is not possible to use json_normalize.
#
# we can still create a dataframe by looping into flavor primary_keywords but i believe it is better to keep the list into the flavor dataframe and access it if needed. moreover to build ML model you don't really need the specific level of each flavor, you can just use the flavor category and use the relative stats.count as flavor weight for that wine.

# %%
def dict_to_table(data, column, key):
    empty_list = []
    for i,j in zip(data[column], data[key]):
        try:
            for n in i:
                n[key] = j
                empty_list.append(n)
        except:
            pass
    return empty_list

# %%
#check null values, if null > 0 we cannot use json_normalize
flavor['primary_keywords'].isna().sum()
# Out:
# np.int64(1100)

# %%
flavor_primary_keywords = pd.DataFrame(dict_to_table(data = flavor, column = 'primary_keywords', key = 'vintage.id' ))
flavor_primary_keywords.head(100)
# Out:
#      id        name  count  vintage.id
# 0   348   raspberry     34   156099154
# 1    93      cherry     28   156099154
# 2   400  strawberry     25   156099154
# 3   354   red fruit     18   156099154
# 4   352  red cherry      5   156099154
# ..  ...         ...    ...         ...
# 95  298      orange      1   156856757
# 96  329   pineapple      2   156856757
# 97  123       cream      1   156856757
# 98   35     biscuit      1   156856757
# 99    6      almond      1   156856757
#
# [100 rows x 4 columns]

# %%
#check null values, if null > 0 we cannot use json_normalize
flavor['secondary_keywords'].isna().sum()
# Out:
# np.int64(6912)

# %%
flavor_secondary_keywords = pd.DataFrame(dict_to_table(data = flavor, column = 'secondary_keywords', key = 'vintage.id' ))
flavor_secondary_keywords.head(100)
# Out:
#      id            name  count  vintage.id
# 0    38    black cherry     14   156099154
# 1   335      plum sauce      2   156099154
# 2   229             jam      1   156099154
# 3   422         tobacco      3   156099154
# 4   134  dark chocolate      3   156099154
# ..  ...             ...    ...         ...
# 95  113           cocoa     15     1746707
# 96   88        charcoal      2     1746707
# 97   14             ash      2     1746707
# 98   65     brown sugar      2     1746707
# 99    6          almond      2     1746707
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Food

# %%
vintage['vintage.wine.style.food'].isna().sum()
# Out:
# np.int64(43)

# %%
food = pd.DataFrame(dict_to_table(data = vintage, column = 'vintage.wine.style.food', key = 'vintage.id' ))
food.head(100)
# Out:
#     id                  name  weight  \
# 0    4                  Beef     0.5
# 1    9                  Veal     0.5
# 2   11  Game (deer, venison)     0.0
# 3   20               Poultry     0.5
# 4    4                  Beef     0.5
# ..  ..                   ...     ...
# 95  11  Game (deer, venison)     0.0
# 96  20               Poultry     0.5
# 97   4                  Beef     0.5
# 98   9                  Veal     0.5
# 99  11  Game (deer, venison)     0.0
#
#                                      background_image seo_name  vintage.id
# 0   {'location': '//images.vivino.com/backgrounds/...     beef   156099154
# 1   {'location': '//images.vivino.com/backgrounds/...     veal   156099154
# 2   {'location': '//images.vivino.com/backgrounds/...     game   156099154
# 3   {'location': '//images.vivino.com/backgrounds/...  poultry   156099154
# 4   {'location': '//images.vivino.com/backgrounds/...     beef   159343591
# ..                                                ...      ...         ...
# 95  {'location': '//images.vivino.com/backgrounds/...     game    87613428
# 96  {'location': '//images.vivino.com/backgrounds/...  poultry    87613428
# 97  {'location': '//images.vivino.com/backgrounds/...     beef   156099154
# 98  {'location': '//images.vivino.com/backgrounds/...     veal   156099154
# 99  {'location': '//images.vivino.com/backgrounds/...     game   156099154
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Grapes

# %%
vintage['vintage.wine.style.grapes'].isna().sum()
# Out:
# np.int64(62)

# %%
grapes = pd.DataFrame(dict_to_table(data = vintage, column = 'vintage.wine.style.grapes', key = 'vintage.id' ))
grapes.head(100)
# Out:
#     id                name            seo_name  has_detailed_info  \
# 0   14          Pinot Noir          pinot-noir               True
# 1    2  Cabernet Sauvignon  cabernet-sauvignon               True
# 2    3      Cabernet Franc      cabernet-franc               True
# 3    9              Malbec              malbec               True
# 4   10              Merlot              merlot               True
# ..  ..                 ...                 ...                ...
# 95  51           Carménère           carmenere               True
# 96   2  Cabernet Sauvignon  cabernet-sauvignon               True
# 97   3      Cabernet Franc      cabernet-franc               True
# 98   9              Malbec              malbec               True
# 99  10              Merlot              merlot               True
#
#     wines_count  parent_grape_id  vintage.id
# 0        572334              NaN   156099154
# 1        801751              NaN   159343591
# 2        269578              NaN   159343591
# 3        219735              NaN   159343591
# 4        566719              NaN   159343591
# ..          ...              ...         ...
# 95        50087              NaN    14162009
# 96       801751              NaN     1759463
# 97       269578              NaN     1759463
# 98       219735              NaN     1759463
# 99       566719              NaN     1759463
#
# [100 rows x 7 columns]
